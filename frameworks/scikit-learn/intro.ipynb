# %% [markdown]
# ## Scikit-Learn

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import pandas as pd

# %%
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True)

# %%
mod = LinearRegression()
mod.fit(X, y)
mod.predict(X)[:3]
# Out:
# array([4.13164983, 3.97660644, 3.67657094])

# %%
mod = KNeighborsRegressor()
mod.fit(X, y)
mod.predict(X)[:3]
# Out:
# array([2.826802, 2.1594  , 3.650404])

# %%
mod = KNeighborsRegressor().fit(X, y)
pred = mod.predict(X)
plt.scatter(pred, y)

# %%
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", KNeighborsRegressor())
])
pred = pipe.fit(X, y).predict(X)
plt.scatter(pred, y)

# %%
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", KNeighborsRegressor(n_neighbors=1))
])
pred = pipe.fit(X, y).predict(X)
plt.scatter(pred, y)

# %%
mod = GridSearchCV(estimator=pipe,
                 param_grid={
                   'model__n_neighbors': [1, 5, 10, 25, 40]
                 },
                 cv=3)
mod.fit(X, y)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('model',
#                                         KNeighborsRegressor(n_neighbors=1))]),
#              param_grid={'model__n_neighbors': [1, 5, 10, 25, 40]})

# %%
pd.DataFrame(mod.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  ...  std_test_score  rank_test_score
# 0       0.020598      0.006916  ...        0.005245                5
# 1       0.016143      0.000283  ...        0.027696                4
# 2       0.014007      0.002459  ...        0.026038                3
# 3       0.017708      0.001736  ...        0.028037                1
# 4       0.015636      0.000215  ...        0.027250                2
#
# [5 rows x 12 columns]

# %% [markdown]
# _________
